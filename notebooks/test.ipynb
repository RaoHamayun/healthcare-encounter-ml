# %%
import pandas as pd
from pathlib import Path

# ==================================================
# CONFIG
# ==================================================
RAW_DATA_PATH = Path("..\\data\\raw")
OUTPUT_PATH = Path("D:\\AIProjects\\AI-Powered Patient Health Monitoring & Predictive Analytics System\\data\\processed")
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)
OUTPUT_FILE = OUTPUT_PATH / "final_healthcare_dataset.csv"

# ==================================================
# SCHEMA
# ==================================================
SCHEMA = {
    "patient": {
        "file": "patients.csv",
        "pk": ["patient_id"],
        "columns": {
            "Id": "patient_id",
            "BIRTHDATE": "birthdate",
            "FIRST": "first_name",
            "LAST": "last_name",
            "MARITAL": "marital_status",
            "RACE": "race",
            "ETHNICITY": "ethnicity",
            "GENDER": "gender",
        },
    },
    "encounter": {
        "file": "encounters.csv",
        "pk": ["patient_id", "encounter_id"],
        "columns": {
            "Id": "encounter_id",
            "PATIENT": "patient_id",
            "ENCOUNTERCLASS": "encounter_class",
            "CODE": "encounter_code",
            "DESCRIPTION": "encounter_description",
        },
    },
    "conditions": {
        "file": "conditions.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CODE": "condition_code",
            "DESCRIPTION": "condition_description",
        },
    },
    "allergies": {
        "file": "allergies.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CODE": "allergy_code",
            "DESCRIPTION": "allergy_description",
            "TYPE": "allergy_type",
            "CATEGORY": "allergy_category",
        },
    },
    "observations": {
        "file": "observations.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CATEGORY": "observation_category",
            "CODE": "observation_code",
            "DESCRIPTION": "observation_description",
        },
    },
    "medications": {
        "file": "medications.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CODE": "medication_code",
            "DESCRIPTION": "medication_description",
        },
    },
    "procedures": {
        "file": "procedures.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CODE": "procedure_code",
            "DESCRIPTION": "procedure_description",
        },
    },
    "careplans": {
        "file": "careplans.csv",
        "fk": ["patient_id", "encounter_id"],
        "columns": {
            "PATIENT": "patient_id",
            "ENCOUNTER": "encounter_id",
            "CODE": "careplan_code",
            "DESCRIPTION": "careplan_description",
        },
    },
}

# ==================================================
# FUNCTIONS
# ==================================================
def load_dataframe(name, cfg, raw_path=RAW_DATA_PATH):
    """Load CSV, select schema columns, rename, and return DataFrame"""
    path = raw_path / cfg["file"]
    df = pd.read_csv(path, usecols=cfg["columns"].keys())
    df = df.rename(columns=cfg["columns"])
    print(f"{name:<12} loaded {df.shape}")
    return df

def impute_missing(df, strategy=None):
    """Impute missing values in a DataFrame"""
    for col in df.columns:
        if strategy and col in strategy:
            df[col] = df[col].fillna(strategy[col])
        else:
            if pd.api.types.is_numeric_dtype(df[col]):
                df[col] = df[col].fillna(0)
            elif pd.api.types.is_datetime64_any_dtype(df[col]):
                df[col] = df[col].fillna(pd.Timestamp("1900-01-01"))
            else:
                df[col] = df[col].fillna("Unknown")
    return df

def check_dataframe(df, name):
    """Print basic info and sample data for a DataFrame"""
    print(f"\n=== {name.upper()} ===")
    print("Shape:", df.shape)
    print("Columns:", df.columns.tolist())
    print("\nMissing values per column:")
    print(df.isnull().sum())
    print("\nDuplicate rows:", df.duplicated().sum())
    print("\nSample rows:")
    print(df.head(3))
    print("-"*50)

def preprocess_dataframe(name, cfg, strategy=None, check=True):
    """Full preprocessing: load, impute, deduplicate"""
    df = load_dataframe(name, cfg)
    df = impute_missing(df, strategy)
    if "pk" in cfg:
        df = df.drop_duplicates(subset=cfg["pk"])
    if check:
        check_dataframe(df, name)
    return df

def aggregate_child_table(df, keys, agg_columns):
    """Aggregate child tables to have one row per encounter"""
    agg_map = {col: lambda x: ", ".join(sorted(set(x.dropna().astype(str)))) for col in agg_columns}
    return df.groupby(keys, as_index=False).agg(agg_map)

# ==================================================
# LOAD AND PREPROCESS ALL DATAFRAMES
# ==================================================
dfs = {name: preprocess_dataframe(name, cfg) for name, cfg in SCHEMA.items()}

# ==================================================
# AGGREGATE CHILD TABLES
# ==================================================
child_tables = ["conditions", "allergies", "observations", "medications", "procedures", "careplans"]
for table in child_tables:
    cfg = SCHEMA[table]
    agg_columns = list(cfg["columns"].values())
    dfs[table] = aggregate_child_table(dfs[table], keys=cfg["fk"], agg_columns=agg_columns)

# ==================================================
# MERGE CORE + CHILD TABLES
# ==================================================
final_df = dfs["encounter"].merge(dfs["patient"], on="patient_id", how="left")
for table in child_tables:
    final_df = final_df.merge(dfs[table], on=["patient_id","encounter_id"], how="left")

# ==================================================
# VALIDATION
# ==================================================
duplicates = final_df.duplicated(subset=["patient_id","encounter_id"]).sum()
print(f"\nDuplicate encounters: {duplicates}")
assert duplicates == 0, "❌ Duplicate encounters found!"

print("\n✅ Final dataset valid")
print("Final shape:", final_df.shape)

# ==================================================
# SAVE FINAL DATASET
# ==================================================
final_df.to_csv(OUTPUT_FILE, index=False)
print(f"\n📁 Saved to: {OUTPUT_FILE}")
# Out:
# patient      loaded (140, 8)
#
# === PATIENT ===
# Shape: (140, 8)
# Columns: ['patient_id', 'birthdate', 'first_name', 'last_name', 'marital_status', 'race', 'ethnicity', 'gender']
#
# Missing values per column:
# patient_id        0
# birthdate         0
# first_name        0
# last_name         0
# marital_status    0
# race              0
# ethnicity         0
# gender            0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                              patient_id   birthdate   first_name  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  1985-10-13   Charles364
# 1  e8503522-82ff-67a2-4dad-29281d6318de  1965-10-07  Leonardo412
# 2  ac643af6-1a32-08ce-df40-1c31348bcb41  1965-10-03     Daren950
#
#        last_name marital_status   race    ethnicity gender
# 0    Buckridge80              S  white  nonhispanic      M
# 1       Berge125              M  white  nonhispanic      M
# 2  Morissette863              M  white  nonhispanic      M
# --------------------------------------------------
# encounter    loaded (12361, 5)
#
# === ENCOUNTER ===
# Shape: (12361, 5)
# Columns: ['encounter_id', 'patient_id', 'encounter_class', 'encounter_code', 'encounter_description']
#
# Missing values per column:
# encounter_id             0
# patient_id               0
# encounter_class          0
# encounter_code           0
# encounter_description    0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                            encounter_id                            patient_id  \
# 0  fa301d15-4761-7c57-6633-5c81cc43d233  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 1  9d4fb2ca-abbd-4270-822a-880cfc94bfb0  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 2  acde7c73-fba1-be42-58ad-314c7c6465a2  f4db39b1-693d-e301-0a1f-41d26d3ced36
#
#   encounter_class  encounter_code         encounter_description
# 0        wellness       410620009  Well child visit (procedure)
# 1       inpatient       183452005           Encounter Inpatient
# 2       inpatient       183452005           Encounter Inpatient
# --------------------------------------------------
# conditions   loaded (7708, 4)
#
# === CONDITIONS ===
# Shape: (7708, 4)
# Columns: ['patient_id', 'encounter_id', 'condition_code', 'condition_description']
#
# Missing values per column:
# patient_id               0
# encounter_id             0
# condition_code           0
# condition_description    0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  fa301d15-4761-7c57-6633-5c81cc43d233
# 1  f4db39b1-693d-e301-0a1f-41d26d3ced36  9d4fb2ca-abbd-4270-822a-880cfc94bfb0
# 2  f4db39b1-693d-e301-0a1f-41d26d3ced36  acde7c73-fba1-be42-58ad-314c7c6465a2
#
#     condition_code                      condition_description
# 0        160968000        Risk activity involvement (finding)
# 1  124171000119105  Chronic intractable migraine without aura
# 2         82423001                               Chronic pain
# --------------------------------------------------
# allergies    loaded (74, 6)
#
# === ALLERGIES ===
# Shape: (74, 6)
# Columns: ['patient_id', 'encounter_id', 'allergy_code', 'allergy_description', 'allergy_type', 'allergy_category']
#
# Missing values per column:
# patient_id             0
# encounter_id           0
# allergy_code           0
# allergy_description    0
# allergy_type           0
# allergy_category       0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  ac643af6-1a32-08ce-df40-1c31348bcb41  5dbe7dd3-5925-dee4-5b6d-2e8ed7fdcd80
# 1  ac643af6-1a32-08ce-df40-1c31348bcb41  5dbe7dd3-5925-dee4-5b6d-2e8ed7fdcd80
# 2  4d3204cc-fbbe-77ba-8a8c-ea49d0422d33  6d82ca24-5092-b4ad-a6b1-5e79d3f0f794
#
#    allergy_code              allergy_description allergy_type allergy_category
# 0         10831  Sulfamethoxazole / Trimethoprim      allergy       medication
# 1     102263004        Eggs (edible) (substance)      allergy             food
# 2      84489001                  Mold (organism)      allergy      environment
# --------------------------------------------------
# observations loaded (100402, 5)
#
# === OBSERVATIONS ===
# Shape: (100402, 5)
# Columns: ['patient_id', 'encounter_id', 'observation_category', 'observation_code', 'observation_description']
#
# Missing values per column:
# patient_id                 0
# encounter_id               0
# observation_category       0
# observation_code           0
# observation_description    0
# dtype: int64
#
# Duplicate rows: 4435
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  081f46f3-78a2-50c6-1312-e412086c9065
# 1  f4db39b1-693d-e301-0a1f-41d26d3ced36  80ab4b8e-da1f-baec-fa92-f5c631440906
# 2  f4db39b1-693d-e301-0a1f-41d26d3ced36  c3357cbf-cfd9-3a09-301c-cb51492eaace
#
#   observation_category observation_code  \
# 0          vital-signs          72514-3
# 1          vital-signs          72514-3
# 2          vital-signs          72514-3
#
#                              observation_description
# 0  Pain severity - 0-10 verbal numeric rating [Sc...
# 1  Pain severity - 0-10 verbal numeric rating [Sc...
# 2  Pain severity - 0-10 verbal numeric rating [Sc...
# --------------------------------------------------
# medications  loaded (14016, 4)
#
# === MEDICATIONS ===
# Shape: (14016, 4)
# Columns: ['patient_id', 'encounter_id', 'medication_code', 'medication_description']
#
# Missing values per column:
# patient_id                0
# encounter_id              0
# medication_code           0
# medication_description    0
# dtype: int64
#
# Duplicate rows: 100
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  081f46f3-78a2-50c6-1312-e412086c9065
# 1  f4db39b1-693d-e301-0a1f-41d26d3ced36  80ab4b8e-da1f-baec-fa92-f5c631440906
# 2  f4db39b1-693d-e301-0a1f-41d26d3ced36  c3357cbf-cfd9-3a09-301c-cb51492eaace
#
#    medication_code                             medication_description
# 0           856987  Acetaminophen 300 MG / HYDROcodone Bitartrate ...
# 1          1860154  Abuse-Deterrent 12 HR Oxycodone Hydrochloride ...
# 2          1049221  Acetaminophen 325 MG / Oxycodone Hydrochloride...
# --------------------------------------------------
# procedures   loaded (20405, 4)
#
# === PROCEDURES ===
# Shape: (20405, 4)
# Columns: ['patient_id', 'encounter_id', 'procedure_code', 'procedure_description']
#
# Missing values per column:
# patient_id               0
# encounter_id             0
# procedure_code           0
# procedure_description    0
# dtype: int64
#
# Duplicate rows: 5462
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  081f46f3-78a2-50c6-1312-e412086c9065
# 1  f4db39b1-693d-e301-0a1f-41d26d3ced36  1179a7b3-53f5-b563-3ae2-a0596c00b8fa
# 2  f4db39b1-693d-e301-0a1f-41d26d3ced36  1179a7b3-53f5-b563-3ae2-a0596c00b8fa
#
#    procedure_code                              procedure_description
# 0        65546002                         Extraction of wisdom tooth
# 1       710824005  Assessment of health and social care needs (pr...
# 2       430193006              Medication Reconciliation (procedure)
# --------------------------------------------------
# careplans    loaded (578, 4)
#
# === CAREPLANS ===
# Shape: (578, 4)
# Columns: ['patient_id', 'encounter_id', 'careplan_code', 'careplan_description']
#
# Missing values per column:
# patient_id              0
# encounter_id            0
# careplan_code           0
# careplan_description    0
# dtype: int64
#
# Duplicate rows: 6
#
# Sample rows:
#                              patient_id                          encounter_id  \
# 0  f4db39b1-693d-e301-0a1f-41d26d3ced36  9de0b17a-f74e-ea88-d90f-dcce3955c1b1
# 1  f4db39b1-693d-e301-0a1f-41d26d3ced36  67da779f-8a39-c406-efd7-4564c0c7550b
# 2  f4db39b1-693d-e301-0a1f-41d26d3ced36  84155c6f-2bed-92f8-c9b4-bf8cac3ac200
#
#    careplan_code                       careplan_description
# 0       53950000                        Respiratory therapy
# 1      773513001  Physiotherapy care plan (record artifact)
# 2       47387005                 Head injury rehabilitation
# --------------------------------------------------
#
# Duplicate encounters: 0
#
# ✅ Final dataset valid
# Final shape: (12361, 27)
#
# 📁 Saved to: D:\AIProjects\AI-Powered Patient Health Monitoring & Predictive Analytics System\data\processed\final_healthcare_dataset.csv

# %%
check_dataframe(final_df, "final_healthcare_dataset")
# Out:
# === FINAL_HEALTHCARE_DATASET ===
# Shape: (12361, 27)
# Columns: ['encounter_id', 'patient_id', 'encounter_class', 'encounter_code', 'encounter_description', 'birthdate', 'first_name', 'last_name', 'marital_status', 'race', 'ethnicity', 'gender', 'condition_code', 'condition_description', 'allergy_code', 'allergy_description', 'allergy_type', 'allergy_category', 'observation_category', 'observation_code', 'observation_description', 'medication_code', 'medication_description', 'procedure_code', 'procedure_description', 'careplan_code', 'careplan_description']
#
# Missing values per column:
# encounter_id                   0
# patient_id                     0
# encounter_class                0
# encounter_code                 0
# encounter_description          0
# birthdate                      0
# first_name                     0
# last_name                      0
# marital_status                 0
# race                           0
# ethnicity                      0
# gender                         0
# condition_code              6800
# condition_description       6800
# allergy_code               12339
# allergy_description        12339
# allergy_type               12339
# allergy_category           12339
# observation_category        7780
# observation_code            7780
# observation_description     7780
# medication_code             5100
# medication_description      5100
# procedure_code              7479
# procedure_description       7479
# careplan_code              11792
# careplan_description       11792
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                            encounter_id                            patient_id  \
# 0  fa301d15-4761-7c57-6633-5c81cc43d233  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 1  9d4fb2ca-abbd-4270-822a-880cfc94bfb0  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 2  acde7c73-fba1-be42-58ad-314c7c6465a2  f4db39b1-693d-e301-0a1f-41d26d3ced36
#
#   encounter_class  encounter_code         encounter_description   birthdate  \
# 0        wellness       410620009  Well child visit (procedure)  1985-10-13
# 1       inpatient       183452005           Encounter Inpatient  1985-10-13
# 2       inpatient       183452005           Encounter Inpatient  1985-10-13
#
#    first_name    last_name marital_status   race  ... allergy_category  \
# 0  Charles364  Buckridge80              S  white  ...              NaN
# 1  Charles364  Buckridge80              S  white  ...              NaN
# 2  Charles364  Buckridge80              S  white  ...              NaN
#
#   observation_category observation_code observation_description  \
# 0                  NaN              NaN                     NaN
# 1                  NaN              NaN                     NaN
# 2                  NaN              NaN                     NaN
#
#   medication_code medication_description procedure_code procedure_description  \
# 0             NaN                    NaN            NaN                   NaN
# 1             NaN                    NaN            NaN                   NaN
# 2             NaN                    NaN            NaN                   NaN
#
#   careplan_code careplan_description
# 0           NaN                  NaN
# 1           NaN                  NaN
# 2           NaN                  NaN
#
# [3 rows x 27 columns]
# --------------------------------------------------

# %%
# Replace NaN with empty string for aggregated child table columns
child_columns = [
    "condition_code", "condition_description",
    "allergy_code", "allergy_description", "allergy_type", "allergy_category",
    "observation_category", "observation_code", "observation_description",
    "medication_code", "medication_description",
    "procedure_code", "procedure_description",
    "careplan_code", "careplan_description"
]

final_df[child_columns] = final_df[child_columns].fillna("")

# %%
final_df["has_condition"] = final_df["condition_code"].apply(lambda x: 0 if x=="" else 1)
final_df["has_allergy"] = final_df["allergy_code"].apply(lambda x: 0 if x=="" else 1)
final_df["has_observation"] = final_df["observation_category"].apply(lambda x: 0 if x=="" else 1)

# %%
check_dataframe(final_df, "final_healthcare_dataset")
# Out:
# === FINAL_HEALTHCARE_DATASET ===
# Shape: (12361, 30)
# Columns: ['encounter_id', 'patient_id', 'encounter_class', 'encounter_code', 'encounter_description', 'birthdate', 'first_name', 'last_name', 'marital_status', 'race', 'ethnicity', 'gender', 'condition_code', 'condition_description', 'allergy_code', 'allergy_description', 'allergy_type', 'allergy_category', 'observation_category', 'observation_code', 'observation_description', 'medication_code', 'medication_description', 'procedure_code', 'procedure_description', 'careplan_code', 'careplan_description', 'has_condition', 'has_allergy', 'has_observation']
#
# Missing values per column:
# encounter_id               0
# patient_id                 0
# encounter_class            0
# encounter_code             0
# encounter_description      0
# birthdate                  0
# first_name                 0
# last_name                  0
# marital_status             0
# race                       0
# ethnicity                  0
# gender                     0
# condition_code             0
# condition_description      0
# allergy_code               0
# allergy_description        0
# allergy_type               0
# allergy_category           0
# observation_category       0
# observation_code           0
# observation_description    0
# medication_code            0
# medication_description     0
# procedure_code             0
# procedure_description      0
# careplan_code              0
# careplan_description       0
# has_condition              0
# has_allergy                0
# has_observation            0
# dtype: int64
#
# Duplicate rows: 0
#
# Sample rows:
#                            encounter_id                            patient_id  \
# 0  fa301d15-4761-7c57-6633-5c81cc43d233  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 1  9d4fb2ca-abbd-4270-822a-880cfc94bfb0  f4db39b1-693d-e301-0a1f-41d26d3ced36
# 2  acde7c73-fba1-be42-58ad-314c7c6465a2  f4db39b1-693d-e301-0a1f-41d26d3ced36
#
#   encounter_class  encounter_code         encounter_description   birthdate  \
# 0        wellness       410620009  Well child visit (procedure)  1985-10-13
# 1       inpatient       183452005           Encounter Inpatient  1985-10-13
# 2       inpatient       183452005           Encounter Inpatient  1985-10-13
#
#    first_name    last_name marital_status   race  ... observation_description  \
# 0  Charles364  Buckridge80              S  white  ...
# 1  Charles364  Buckridge80              S  white  ...
# 2  Charles364  Buckridge80              S  white  ...
#
#   medication_code medication_description procedure_code procedure_description  \
# 0
# 1
# 2
#
#   careplan_code careplan_description has_condition has_allergy has_observation
# 0                                                1           0               0
# 1                                                1           0               0
# 2                                                1           0               0
#
# [3 rows x 30 columns]
# --------------------------------------------------

# %%
final_df
# Out:
#                                encounter_id  \
# 0      fa301d15-4761-7c57-6633-5c81cc43d233
# 1      9d4fb2ca-abbd-4270-822a-880cfc94bfb0
# 2      acde7c73-fba1-be42-58ad-314c7c6465a2
# 3      aaf60ab9-3f5e-2ff1-8300-a2dbdacb04ce
# 4      96e42627-d0ab-7e1a-30dc-0731aa49151f
# ...                                     ...
# 12356  2fb7287e-56f3-bc4a-7f4b-4e9f3f042c76
# 12357  ec82ab7a-4b64-c4d1-13e4-adecec9bd11d
# 12358  262997ae-a23e-6b89-aefb-76a6c8bdfa85
# 12359  cdc5fecc-5023-1053-ec60-6ce032edb99b
# 12360  7a9866bc-90d7-3c29-0a83-04ed2bbba561
#
#                                  patient_id encounter_class  encounter_code  \
# 0      f4db39b1-693d-e301-0a1f-41d26d3ced36        wellness       410620009
# 1      f4db39b1-693d-e301-0a1f-41d26d3ced36       inpatient       183452005
# 2      f4db39b1-693d-e301-0a1f-41d26d3ced36       inpatient       183452005
# 3      f4db39b1-693d-e301-0a1f-41d26d3ced36       inpatient       183452005
# 4      f4db39b1-693d-e301-0a1f-41d26d3ced36        wellness       410620009
# ...                                     ...             ...             ...
# 12356  62cc7665-709d-576e-052a-bdc7eae265be      outpatient        33879002
# 12357  62cc7665-709d-576e-052a-bdc7eae265be      ambulatory       390906007
# 12358  62cc7665-709d-576e-052a-bdc7eae265be        wellness       162673000
# 12359  62cc7665-709d-576e-052a-bdc7eae265be      ambulatory       390906007
# 12360  62cc7665-709d-576e-052a-bdc7eae265be        wellness       162673000
#
#                                    encounter_description   birthdate  \
# 0                           Well child visit (procedure)  1985-10-13
# 1                                    Encounter Inpatient  1985-10-13
# 2                                    Encounter Inpatient  1985-10-13
# 3                                    Encounter Inpatient  1985-10-13
# 4                           Well child visit (procedure)  1985-10-13
# ...                                                  ...         ...
# 12356  Administration of vaccine to produce active im...  1928-04-26
# 12357                                Follow-up encounter  1928-04-26
# 12358         General examination of patient (procedure)  1928-04-26
# 12359                                Follow-up encounter  1928-04-26
# 12360         General examination of patient (procedure)  1928-04-26
#
#        first_name     last_name marital_status   race  ...  \
# 0      Charles364   Buckridge80              S  white  ...
# 1      Charles364   Buckridge80              S  white  ...
# 2      Charles364   Buckridge80              S  white  ...
# 3      Charles364   Buckridge80              S  white  ...
# 4      Charles364   Buckridge80              S  white  ...
# ...           ...           ...            ...    ...  ...
# 12356     Lela622  Bahringer146              M  white  ...
# 12357     Lela622  Bahringer146              M  white  ...
# 12358     Lela622  Bahringer146              M  white  ...
# 12359     Lela622  Bahringer146              M  white  ...
# 12360     Lela622  Bahringer146              M  white  ...
#
#                                  observation_description  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 12356
# 12357  Alanine aminotransferase [Enzymatic activity/v...
# 12358  Are you Hispanic or Latino?, Are you a refugee...
# 12359  Alanine aminotransferase [Enzymatic activity/v...
# 12360  Are you Hispanic or Latino?, Are you a refugee...
#
#                                          medication_code  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 12356
# 12357                                             314231
# 12358  197361, 206905, 309362, 310798, 312961, 314076...
# 12359                                             314231
# 12360  197361, 206905, 309362, 310798, 312961, 314076...
#
#                                   medication_description  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 12356
# 12357                      Simvastatin 10 MG Oral Tablet
# 12358  Amlodipine 5 MG Oral Tablet, Clopidogrel 75 MG...
# 12359                      Simvastatin 10 MG Oral Tablet
# 12360  Amlodipine 5 MG Oral Tablet, Clopidogrel 75 MG...
#
#                                           procedure_code  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 12356
# 12357
# 12358  171207006, 428211000124100, 454711000124102, 7...
# 12359
# 12360  171207006, 428211000124100, 430193006, 4547110...
#
#                                    procedure_description careplan_code  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...           ...
# 12356
# 12357
# 12358  Assessment of health and social care needs (pr...
# 12359
# 12360  Assessment of health and social care needs (pr...
#
#       careplan_description has_condition has_allergy has_observation
# 0                                      1           0               0
# 1                                      1           0               0
# 2                                      1           0               0
# 3                                      1           0               0
# 4                                      1           0               0
# ...                    ...           ...         ...             ...
# 12356                                  0           0               0
# 12357                                  0           0               1
# 12358                                  1           0               1
# 12359                                  0           0               1
# 12360                                  1           0               1
#
# [12361 rows x 30 columns]

# %%
final_df.to_csv(OUTPUT_FILE, index=False)
print(f"\n📁 Saved to: {OUTPUT_FILE}")
# Out:
# 📁 Saved to: D:\AIProjects\AI-Powered Patient Health Monitoring & Predictive Analytics System\data\processed\final_healthcare_dataset.csv
